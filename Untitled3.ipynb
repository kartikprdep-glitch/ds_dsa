# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None

# %%
n1=Node("andhu")
n2=Node("arthi")
n3=Node("thika")

# %%
n1.next=n2
n1.prev=None

# %%
n2.next=n3
n2.prev=n1

# %%
n3.next=None
n3.prev=n2

# %%
cur=n1
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# andhu
# arthi
# thika

# %%
print(n1.next.next.data)
# Out:
# thika

# %%
print(n2.prev.next.data)
# Out:
# arthi

# %%
n1=Node(500)
n2=Node(200)
n3=Node(300)
n0=Node(100)

# %%
n1.next=n2
n1.prev=None
n2.next=n3
n2.prev=n1
n3.next=None
n3.prev=n2

# %%
cur=n1
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 500
# 200
# 300

# %%
n0.next=n1
n0.prev=None
n1.prev=n0
cur=n0
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 100
# 500
# 200
# 300

# %%
n11=Node(400)
n11.next=None
n11.prev=n3
n3.next=n11
cur=n0
while cur:     
    print(cur.data)
    cur=cur.next
# Out:
# 100
# 500
# 200
# 300
# 400
